# %%
# !pip install kagglehub

# %% [markdown]
# # бинарная классификация текста (positive / negative)

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pawankumargunjan/imdb-review")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/pawankumargunjan/imdb-review?dataset_version_number=3...
# 100%|██████████| 111M/111M [00:12<00:00, 9.42MB/s]
# Extracting files...
# Path to dataset files: C:\Users\bakru_b9pmn2k\.cache\kagglehub\datasets\pawankumargunjan\imdb-review\versions\3

# %% [markdown]
# # NER — Named Entity Recognition

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("alaakhaled/conll003-englishversion")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/alaakhaled/conll003-englishversion?dataset_version_number=1...
# 100%|██████████| 960k/960k [00:00<00:00, 1.36MB/s]
# Extracting files...
# Path to dataset files: C:\Users\bakru_b9pmn2k\.cache\kagglehub\datasets\alaakhaled\conll003-englishversion\versions\1

# %% [markdown]
# Content
# This dataset is divided into train.txt, test.txt and valid.txt
#
# The Tokens are labeled under one of the following tags [
# I-LOC
# B-ORG
# O
# B-PER
# I-PER
# I-MISC
# B-MISC
# I-ORG
# B-LOC]

# %% [markdown]
# # Stanford Natural Language Inference

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("stanfordu/stanford-natural-language-inference-corpus")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/stanfordu/stanford-natural-language-inference-corpus?dataset_version_number=1...
# 100%|██████████| 44.4M/44.4M [00:04<00:00, 11.5MB/s]
# Extracting files...
# Path to dataset files: C:\Users\bakru_b9pmn2k\.cache\kagglehub\datasets\stanfordu\stanford-natural-language-inference-corpus\versions\1
