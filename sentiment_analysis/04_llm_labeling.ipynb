# %%
import sys
import os

module_path = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
from ai_service import label_dataset_comments, AiClient

# %%
ai_service = AiClient()

# %%
train = pd.read_csv('../data/amdb_dataset/train/train_combined.csv')
test = pd.read_csv('../data/amdb_dataset/test/test_combined.csv')

    
train = train.sample(frac=1, random_state=42).reset_index(drop=True)
test = test.sample(frac=1, random_state=42).reset_index(drop=True)


train
# Out:
#                                                    text  mark  label
# 0     Despite the high ratings given to this film by...     2      0
# 1     That's the question you have to ask yourself w...     2      0
# 2     I really wish that when making a comedy, the p...     1      0
# 3     This is a very bland and inert production of o...     2      0
# 4     Amateurism best describes the film adaptation ...     1      0
# ...                                                 ...   ...    ...
# 1435  This movie was my first touch with Mr Sica so ...     9      1
# 1436  SPOILERS All too often, Hollywood's Shakespear...     1      0
# 1437  Jackie Chan's Police Story is a landmark film ...     9      1
# 1438  This is how i felt while watching this film. I...    10      1
# 1439  what a preposterous story ,murder blackmail,ch...     4      0
#
# [1440 rows x 3 columns]

# %% [markdown]
# ## the best promt found

# %%
expert_linguist = [
    {
        "role": "system",
        "content": "You are an expert computational linguist specializing in sentiment analysis of user reviews. "
                   "Analyze the nuances, tone, and context of the text below. "
                    "Even if the text contains mixed emotions, determine the predominant polarity. "
                   "Return ONLY the label: Positive or Negative.",
    },
    {
        "role": "user",
        "content": "Text: {text}\nLabel:",
    }
]

# %% [markdown]
# ## A dataset developed for gpt-4o, which was unfortunately lost

# %%
res_df, metrics = label_dataset_comments(train, expert_linguist, "gpt-4o", ai_service.apenai_call)

metrics
# Out:
# 100%|██████████| 1440/1440 [18:18<00:00,  1.31it/s]
# {'count': 1440,
#  'avg_time': 0.7609076160523627,
#  'total_cost_tokens': 518677,
#  'sum_prompt_tokens': 517237,
#  'sum_completion_tokens': 1440,
#  'errors': 0}

# %%
res_df['pred_label'].value_counts()
# Out:
# pred_label
# 0    765
# 1    675
# Name: count, dtype: int64

# %% [markdown]
# ## gpt-4o-mini

# %%
res_df, metrics = label_dataset_comments(train, expert_linguist, "gpt-4o-mini", ai_service.apenai_call)

metrics
# Out:
# 100%|██████████| 1440/1440 [15:20<00:00,  1.56it/s]
# {'count': 1440,
#  'avg_time': 0.6375422777401076,
#  'total_cost_tokens': 518677,
#  'sum_prompt_tokens': 517237,
#  'sum_completion_tokens': 1440,
#  'errors': 0}

# %%
res_df
# Out:
#                                                    text  mark  label  \
# 0     Despite the high ratings given to this film by...     2      0
# 1     That's the question you have to ask yourself w...     2      0
# 2     I really wish that when making a comedy, the p...     1      0
# 3     This is a very bland and inert production of o...     2      0
# 4     Amateurism best describes the film adaptation ...     1      0
# ...                                                 ...   ...    ...
# 1435  This movie was my first touch with Mr Sica so ...     9      1
# 1436  SPOILERS All too often, Hollywood's Shakespear...     1      0
# 1437  Jackie Chan's Police Story is a landmark film ...     9      1
# 1438  This is how i felt while watching this film. I...    10      1
# 1439  what a preposterous story ,murder blackmail,ch...     4      0
#
#       pred_raw  pred_label  time_sec  prompt_tokens  completion_tokens  \
# ...

# %% [markdown]
# ## gemini-2.0-flash

# %%
res_df, metrics = label_dataset_comments(train, expert_linguist, "gemini-2.0-flash", ai_service.gemini_call)

metrics
# Out:
# 100%|██████████| 1440/1440 [11:32<00:00,  2.08it/s]
# {'count': 1440,
#  'avg_time': 0.47921536796622805,
#  'total_cost_tokens': 512382,
#  'sum_prompt_tokens': 509502,
#  'sum_completion_tokens': 2880,
#  'errors': 0}

# %%
res_df
# Out:
#                                                    text  mark  label  \
# 0     Despite the high ratings given to this film by...     2      0
# 1     That's the question you have to ask yourself w...     2      0
# 2     I really wish that when making a comedy, the p...     1      0
# 3     This is a very bland and inert production of o...     2      0
# 4     Amateurism best describes the film adaptation ...     1      0
# ...                                                 ...   ...    ...
# 1435  This movie was my first touch with Mr Sica so ...     9      1
# 1436  SPOILERS All too often, Hollywood's Shakespear...     1      0
# 1437  Jackie Chan's Police Story is a landmark film ...     9      1
# 1438  This is how i felt while watching this film. I...    10      1
# 1439  what a preposterous story ,murder blackmail,ch...     4      0
#
#       pred_raw  pred_label  time_sec  prompt_tokens  completion_tokens  \
# ...

# %% [markdown]
# ## claude-3-5-haiku

# %%
train = pd.read_csv('../data/amdb_dataset/train/train_combined.csv')    
train = train.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
res_df, metrics = label_dataset_comments(train, expert_linguist, "claude-3-5-haiku-20241022", ai_service.anthropic_call)

metrics
# Out:
# 100%|██████████| 1440/1440 [28:01<00:00,  1.17s/it]
# {'count': 1440,
#  'avg_time': 1.1653865706589488,
#  'total_cost_tokens': 573156,
#  'sum_prompt_tokens': 565698,
#  'sum_completion_tokens': 7458,
#  'errors': 0}

# %%
preds = pd.read_csv("predictions_train_claude-3-5-haiku.csv")
preds.head()
# Out:
#                                                 text  mark  label  pred_raw  \
# 0  Despite the high ratings given to this film by...     2      0  Negative
# 1  That's the question you have to ask yourself w...     2      0  Negative
# 2  I really wish that when making a comedy, the p...     1      0  Negative
# 3  This is a very bland and inert production of o...     2      0  Negative
# 4  Amateurism best describes the film adaptation ...     1      0  Negative
#
#    pred_label  time_sec  prompt_tokens  completion_tokens  total_tokens
# 0           0  1.183462            155                  5           160
# 1           0  0.795043            702                  5           707
# 2           0  0.571386            186                  5           191
# 3           0  0.781936            391                  5           396
# 4           0  0.761473            239                  5           244
