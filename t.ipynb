# %%
import pandas as pd

# %%
df1 = pd.read_csv('sentiment_analysis/predictions_train_gpt-4o.csv')
df2 = pd.read_csv('sentiment_analysis/predictions_train_gemini_flash.csv')

# %%
df1
# Out:
#       Unnamed: 0                                               text  mark  \
# 0              0  Despite the high ratings given to this film by...     2
# 1              1  That's the question you have to ask yourself w...     2
# 2              2  I really wish that when making a comedy, the p...     1
# 3              3  This is a very bland and inert production of o...     2
# 4              4  Amateurism best describes the film adaptation ...     1
# ...          ...                                                ...   ...
# 1435        1435  This movie was my first touch with Mr Sica so ...     9
# 1436        1436  SPOILERS All too often, Hollywood's Shakespear...     1
# 1437        1437  Jackie Chan's Police Story is a landmark film ...     9
# 1438        1438  This is how i felt while watching this film. I...    10
# 1439        1439  what a preposterous story ,murder blackmail,ch...     4
#
#       label  pred_raw  pred_label  time_sec  prompt_tokens  completion_tokens  \
# ...

# %%
df2
# Out:
#                                                    text  mark  label  \
# 0     Despite the high ratings given to this film by...     2      0
# 1     That's the question you have to ask yourself w...     2      0
# 2     I really wish that when making a comedy, the p...     1      0
# 3     This is a very bland and inert production of o...     2      0
# 4     Amateurism best describes the film adaptation ...     1      0
# ...                                                 ...   ...    ...
# 1435  This movie was my first touch with Mr Sica so ...     9      1
# 1436  SPOILERS All too often, Hollywood's Shakespear...     1      0
# 1437  Jackie Chan's Police Story is a landmark film ...     9      1
# 1438  This is how i felt while watching this film. I...    10      1
# 1439  what a preposterous story ,murder blackmail,ch...     4      0
#
#       pred_raw  pred_label  time_sec  prompt_tokens  completion_tokens  \
# ...
